# %%
text = "I like NLP I like Python NLP is fun"

words = text.split();

words
# Out:
# ['I', 'like', 'NLP', 'I', 'like', 'Python', 'NLP', 'is', 'fun']

# %%
word_dict = {word: words.count(word) for word in set(words)}
word_dict
# Out:
# {'fun': 1, 'Python': 1, 'is': 1, 'NLP': 2, 'like': 2, 'I': 2}

# %%
for key in word_dict:
    print(f"'{key}' appears {word_dict[key]} times")
# Out:
# 'fun' appears 1 times
# 'Python' appears 1 times
# 'is' appears 1 times
# 'NLP' appears 2 times
# 'like' appears 2 times
# 'I' appears 2 times
