# %%
courpus = [
    "I like NLP",
    "I like AI",
    "AI is amazing"
]

# %%
all_words = []

# %%
for text in courpus:
    words = text.split()
    all_words.append(words)

# %%
vocabulary = set(all_words)
